# %%
import utils as u
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="dark")

# %%
data = u.prepare_data("SIM-01-26-2022-15:29.log")

# %%
ud = u.update_delay(data,"1")
kwargs = {'cumulative': True}
f, (ax_normal, ax_log) = plt.subplots(figsize=(15, 7),ncols=2, nrows=1, sharey=True, gridspec_kw={'wspace':0.01})
ax_normal.axvline(100, ls='--', color='r')
ax_log.set(xscale="log")

b = sns.distplot(ud,ax=ax_normal , kde_kws=kwargs)
a = sns.distplot(ud,ax=ax_log , kde_kws=kwargs)

b.set(xlim=(0,150))
a.set(xlim=(150,None))

# sns.despine(ax=ax_normal)
# sns.despine(ax=ax_log)


ax = ax_log
d = .02  # how big to make the diagonal lines in axes coordinates
# arguments to pass to plot, just so we don't keep repeating them
kwargs = dict(transform=ax.transAxes, color='k', clip_on=False)
ax.plot((-d, +d), (-d, +d), **kwargs)        # top-left diagonal
kwargs = dict(transform=ax.transAxes, color='k', clip_on=False)
ax.plot((-d, +d), (1-d, 1+d), **kwargs)        # top-left diagonal

ax2 = ax_normal
kwargs.update(transform=ax2.transAxes)  # switch to the bottom axes
ax2.plot((1-d, 1+d), (- d,  d), **kwargs)  # bottom-left diagonal
kwargs = dict(transform=ax2.transAxes, color='k', clip_on=False)
ax.plot((1-d, 1+d), (1-d, 1+d), **kwargs) 


plt.show()

# %%
a = u.e2e_latency_all_ue(data)
# Out:
# /home/tqaei/Desktop/Learning/data_viz/utils.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(e2e_latency_by_ue(data,ue))
# /home/tqaei/Desktop/Learning/data_viz/utils.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(e2e_latency_by_ue(data,ue))
# /home/tqaei/Desktop/Learning/data_viz/utils.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(e2e_latency_by_ue(data,ue))

# %% [markdown]
# # Latency by vehicle

# %%
sns.violinplot(data=a, palette="Pastel1")
plt.show()

# %%
sns.violinplot( y= "latency",data=a,hue="latency", palette="Pastel1")
plt.show()

# %%
sns.boxplot(y=a["latency"] )
# Out:
# <AxesSubplot:ylabel='latency'>

# %%
kwargs = {'cumulative': True}
sns.displot(a["latency"],ylabel='Density', hist_kws=kwargs, kde_kws=kwargs)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Desktop/Learning/data_viz/env/lib/python3.8/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/Desktop/Learning/data_viz/env/lib/python3.8/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/Desktop/Learning/data_viz/env/lib/python3.8/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'latency'
#
# ...
